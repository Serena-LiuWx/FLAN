# %% [markdown]
# <a href="https://colab.research.google.com/github/Serena-LiuWx/FLAN/blob/main/FLAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/google-research/FLAN.git
# Out:
# Cloning into 'FLAN'...
# remote: Enumerating objects: 357, done.
# remote: Counting objects: 100% (264/264), done.
# remote: Compressing objects: 100% (102/102), done.
# remote: Total 357 (delta 217), reused 162 (delta 162), pack-reused 93
# Receiving objects: 100% (357/357), 149.94 MiB | 31.89 MiB/s, done.
# Resolving deltas: 100% (222/222), done.
# Updating files: 100% (58/58), done.

# %%
# !python FLAN/flan/mixtures.py
# Out:
# 2023-05-14 18:32:32.587691: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-14 18:32:34.234239: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Traceback (most recent call last):
#   File "/content/FLAN/flan/mixtures.py", line 21, in <module>
#     import task_splits
#   File "/content/FLAN/flan/task_splits.py", line 25, in <module>
#     import tasks as flan_tasks  # pylint: disable=unused-import
#   File "/content/FLAN/flan/tasks.py", line 2274, in <module>
#     seqio.TaskRegistry.add(
#   File "/usr/local/lib/python3.10/dist-packages/seqio/dataset_providers.py", line 1109, in add
#     return super().add(name, Task, name, source, output_features, preprocessors,
# ...

# %%
# !pip install seqio
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 332.6/332.6 kB 6.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 11.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 505.6/505.6 kB 26.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 56.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 69.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 35.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 9.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for ml-collections: filename=ml_collections-0.1.1-py3-none-any.whl size=94506 sha256=24813cbcc1a8dd4d0260388d0b5dfc7ad88ffa8da1929ebc12b368840c09c091
#   Stored in directory: /root/.cache/pip/wheels/7b/89/c9/a9b87790789e94aadcfc393c283e3ecd5ab916aed0a31be8fe
# ...

# %%
# !export PYTHONPATH=/content/FLAN:$PYTHONPATH

# %%
# !pip install tensorrt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for tensorrt: filename=tensorrt-8.6.1-py2.py3-none-any.whl size=16973 sha256=5dbb1512873ce9cbe49ab7e38f93df0fe3fa63ac8a2360de7495814bfe96d79e
#   Stored in directory: /root/.cache/pip/wheels/6d/29/56/abdffd4c604f255b5254bef3f1c598ab7811ea020540599438
# Successfully built tensorrt
# ...

# %%
# !python /content/FLAN/flan/mixtures.py
# Out:
# 2023-05-14 19:13:03.051384: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-05-14 19:13:07.512823: W tensorflow/tsl/platform/cloud/google_auth_provider.cc:184] All attempts to get a Google authentication bearer token failed, returning an empty token. Retrieving token from files failed with "NOT_FOUND: Could not locate the credentials file.". Retrieving token from GCE failed with "NOT_FOUND: Error executing an HTTP request: HTTP response code 404".
# WARNING:absl:Task 'bool_q_10templates' not cached so using number of input examples instead of preprocessed examples to compute rate.
# WARNING:absl:Task 'snli_10templates' not cached so using number of input examples instead of preprocessed examples to compute rate.
# ...

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- ---------------------
# absl-py                       1.4.0
# alabaster                     0.7.13
# albumentations                1.2.1
# altair                        4.2.2
# anyio                         3.6.2
# appdirs                       1.4.4
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# array-record                  0.2.0
# arviz                         0.15.1
# astropy                       5.2.2
# astunparse                    1.6.3
# attrs                         23.1.0
# audioread                     3.0.0
# autograd                      1.5
# Babel                         2.12.1
# backcall                      0.2.0
# beautifulsoup4                4.11.2
# bleach                        6.0.0
# blis                          0.7.9
# blosc2                        2.0.0
# bokeh                         2.4.3
# branca                        0.6.0
# ...
